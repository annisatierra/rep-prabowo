# %%
import pandas as pd

# %%
df = pd.read_excel("Data Output Twitter.xlsx")
df.drop(['Unnamed: 0'], axis = 1, inplace= True)
df.tail()
# Out:
#                        FileName               css-175oi2r href  \
# 4649  1853461890472804795_reply  https://x.com/modernize74ripe
# 4650  1853461890472804795_reply         https://x.com/abunadhr
# 4651  1853461890472804795_reply         https://x.com/abunadhr
# 4652  1853461890472804795_reply          https://x.com/xlsatu_
# 4653  1853461890472804795_reply  https://x.com/PijatCilegonFYP
#
#                                          css-9pa8cd src r-4qtqp9 src  \
# 4649  https://pbs.twimg.com/profile_images/185329916...          NaN
# 4650  https://pbs.twimg.com/profile_images/176154933...          NaN
# 4651  https://pbs.twimg.com/profile_images/176154933...          NaN
# 4652  https://pbs.twimg.com/profile_images/175986141...          NaN
# 4653  https://pbs.twimg.com/profile_images/177238296...          NaN
#
#                                css-1jxf684     css-1jxf684 2 css-1jxf684 3  \
# 4649                           meongfoodie  @modernize74ripe             ·
# ...

# %%
df.columns
# Out:
# Index(['FileName', 'css-175oi2r href', 'css-9pa8cd src', 'r-4qtqp9 src',
#        'css-1jxf684', 'css-1jxf684 2', 'css-1jxf684 3', 'css-146c3p1 href',
#        'css-146c3p1', 'css-1jxf684 4', 'css-1jxf684 5', 'css-9pa8cd src 2',
#        'css-1jxf684 6', 'css-1jxf684 7', 'css-1jxf684 8', 'css-146c3p1 2',
#        'css-146c3p1 href 2', 'css-175oi2r href 4', 'css-1jxf684 15',
#        'css-175oi2r href 5', 'css-1jxf684 16', 'css-9pa8cd src 3',
#        'css-1jxf684 href', 'css-1jxf684 9', 'css-1jxf684 10', 'css-1jxf684 11',
#        'css-1jxf684 12', 'css-175oi2r href 6', 'css-9pa8cd src 4',
#        'public-DraftEditorPlaceholder-inner', 'css-1jxf684 13',
#        'css-1jxf684 href 2', 'r-4qtqp9 src 2', 'r-4qtqp9 src 3',
#        'r-4qtqp9 src 4', 'r-4qtqp9 src 5', 'r-4qtqp9 src 6', 'r-4qtqp9 href',
#        'css-1jxf684 14', 'css-175oi2r href 7', 'css-175oi2r href 8',
#        'css-9pa8cd src 5', 'css-175oi2r href 9', 'css-9pa8cd src 6',
# ...

# %%
df = df.rename(columns={
    'css-146c3p1 href':'Link',
    'css-1jxf684 4' : 'Text',
    'css-1jxf684 16' : 'Tayangan',
    'css-1jxf684 15' :'Like',
    'css-1jxf684 15' : 'Reply',
    'css-1jxf684 5' : 'Retweet'
})

# %%
df_eko = df[df['FileName']=='1854498933441212530_reply']
df_eko.head()
# Out:
#                        FileName               css-175oi2r href  \
# 4195  1854498933441212530_reply       https://x.com/phak_luyak
# 4196  1854498933441212530_reply   https://x.com/MohSalim299487
# 4197  1854498933441212530_reply  https://x.com/alexand66298416
# 4198  1854498933441212530_reply        https://x.com/AndisBoga
# 4199  1854498933441212530_reply         https://x.com/Dewina02
#
#                                          css-9pa8cd src r-4qtqp9 src  \
# 4195  https://pbs.twimg.com/profile_images/184723035...          NaN
# 4196  https://pbs.twimg.com/profile_images/171976884...          NaN
# 4197  https://pbs.twimg.com/profile_images/172250690...          NaN
# 4198  https://pbs.twimg.com/profile_images/158879345...          NaN
# 4199  https://pbs.twimg.com/profile_images/178410627...          NaN
#
#          css-1jxf684     css-1jxf684 2 css-1jxf684 3  \
# 4195  Wamen domisili       @phak_luyak             ·
# 4196           Comet   @MohSalim299487             ·
# ...

# %% [markdown]
# # Topic Modelling

# %%
# %pip install bertopic
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\Annisa Sekar Tierra\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
